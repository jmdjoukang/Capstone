# %%
# Import necessary libraries
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import panel as pn
import pandas as pd
import hvplot.pandas  # Import the hvplot library

# %%
# Load your data
df = pd.read_csv('survey_data.csv', encoding='ISO-8859-1')

# %%
# Display the first 5 rows of the dataframe
print(df.head())
# Out:
#    ï»¿household_size  dwelling_type                            attitude  \
# 0                  5  Semi_detached                  Somewhat satisfied
# 1                  5      Apartment  Neither satisfied nor dissatisfied
# 2                  3      Apartment                      Very satisfied
# 3                  5  Semi_detached                      Very satisfied
# 4                  6       Detached                      Very satisfied
#
#   weather_effects_on_electricity_consumption  \
# 0                             Strongly agree
# 1                             Somewhat agree
# 2                                    Neutral
# 3                             Strongly agree
# 4                             Somewhat agree
#
#   weather_conditions_most_affecting awareness_about_energy_policies  \
# 0                     Precipitation               Somewhat informed
# 1                              Wind             Somewhat uninformed
# ...

# %%
# Print all existing columns
print(df.columns)
# Out:
# Index(['ï»¿household_size', 'dwelling_type', 'attitude',
#        'weather_effects_on_electricity_consumption',
#        'weather_conditions_most_affecting', 'awareness_about_energy_policies',
#        'weather-based_energy_management_strategies_adoption', 'challenges',
#        'monitoring', 'checking_consumption',
#        'appliances_using_the_most_electricity',
#        'self_reported_peak_consumption_times', 'provider_info_rating', 'age',
#        'education', 'occupation', 'income', 'comments'],
#       dtype='object')

# %%
# Get the summary statistics for the 'income' column
print(df['income'].describe())
# Out:
# count        197
# unique         5
# top       0k-20k
# freq          53
# Name: income, dtype: object

# %%
# Get the count of each unique value in the 'education' column
print(df['education'].value_counts())
# Out:
# education
# Bachelor's degree                    62
# Some college                         46
# High school diploma or equivalent    41
# Master's degree or higher            38
# Less than high school                10
# Name: count, dtype: int64

# %%
# Get the count of each unique value in the 'knowledge_about_weather_energy' column
print(df['provider_info_rating'].value_counts())
# Out:
# provider_info_rating
# Neutral            71
# Very poorly        59
# Somewhat poorly    30
# Very well          22
# Somewhat well      11
# well                4
# Name: count, dtype: int64

# %%
# Get the count of each unique value in the 'attitude' column
print(df['attitude'].value_counts())
# Out:
# attitude
# Neither satisfied nor dissatisfied    62
# Somewhat satisfied                    58
# Somewhat dissatisfied                 47
# Very satisfied                        19
# Very dissatisfied                     11
# Name: count, dtype: int64

# %%
# Get 
print(df['weather_effects_on_electricity_consumption'].value_counts())
# Out:
# weather_effects_on_electricity_consumption
# Somewhat agree       56
# Somewhat disagree    52
# Strongly agree       41
# Neutral              35
# Strongly disagree    13
# Name: count, dtype: int64

# %%
# Get 
print(df['weather_conditions_most_affecting'].value_counts())
# Out:
# weather_conditions_most_affecting
# Humidity                           54
# Wind, Humidity                     43
# Precipitation                      38
# Wind                               13
# Precipitation, Wind, Humidity      13
# Precipitation, Humidity            10
# Humidity, Wind                      9
# Humidity, Humidity                  8
# Precipitation, Wind                 8
# Precipitation, Wind, Humidity,      1
# Name: count, dtype: int64

# %%
# Get 
print(df['weather-based_energy_management_strategies_adoption'].value_counts())
# Out:
# weather-based_energy_management_strategies_adoption
# Washing clothes in cold water during hot weather                                                                                                             67
# Adjusting your thermostat settings based on the weather forecast                                                                                             46
# Using energy-efficient appliances whenever possible                                                                                                          30
# Unplugging unused electronics                                                                                                                                17
# Washing clothes in cold water during hot weather, Taking shorter showers in hot weather                                                                       7
# ...

# %%
# Get 
print(df['awareness_about_energy_policies'].value_counts())
# Out:
# awareness_about_energy_policies
# Somewhat uninformed    91
# Somewhat informed      78
# Very informed          18
# Very uninformed        10
# Name: count, dtype: int64

# %%
# Get 
print(df['self_reported_peak_consumption_times'].value_counts())
# Out:
# self_reported_peak_consumption_times
# Sathurday     81
# weekend       55
# holidays      27
# Evening       13
# Sathurday      5
# Everyday       2
# Sunday         2
# Evening        1
# Morning        1
# Evening        1
# weekend        1
# Friday         1
# Negative       1
# Sundays        1
# holidays       1
# Sunday         1
# Every day      1
# evening        1
# Monday         1
# Name: count, dtype: int64

# %%
# Pie chart
df['self_reported_peak_consumption_times'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of peak consumption times')
plt.show()

# %%
# Pie chart
df['weather_conditions_most_affecting'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of weather conditions most affecting')
plt.show()

# %%
# Pie chart
df['attitude'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of attitude toward weather-based energy management strategies')
plt.show()

# %%
# Pie chart
df['education'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of respondant education level')
plt.show()

# %%
# Pie chart
df['awareness_about_energy_policies'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of awareness about energy policies')
plt.show()

# %%
# Pie chart
df['weather-based_energy_management_strategies_adoption'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of strategies adoption actions')
plt.show()

# %%
# Pie chart
df['income'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of income')
plt.show()

# %%
# Pie chart
df['provider_info_rating'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of provider info rating')
plt.show()

# %%
# Pie chart
df['dwelling_type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of respondants dwelling type')
plt.show()

# %%
# Pie chart
df['appliances_using_the_most_electricity'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of appliances using the most electricity')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('survey_data.csv')

# %%
df.head()
# Out:
#    household_size  dwelling_type                            attitude  \
# 0               5  Semi_detached                  Somewhat satisfied
# 1               5      Apartment  Neither satisfied nor dissatisfied
# 2               3      Apartment                      Very satisfied
# 3               5  Semi_detached                      Very satisfied
# 4               6       Detached                      Very satisfied
#
#   weather_effects_on_electricity_consumption  \
# 0                             Strongly agree
# 1                             Somewhat agree
# 2                                    Neutral
# 3                             Strongly agree
# 4                             Somewhat agree
#
#   weather_conditions_most_affecting awareness_about_energy_policies  \
# 0                     Precipitation               Somewhat informed
# 1                              Wind             Somewhat uninformed
# ...

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='education', y='attitude')
plt.title('Adoption Trend for education vs attitude')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='income', y='attitude')
plt.title('Adoption Trend for income vs attitude')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='provider_info_rating', y='attitude')
plt.title('Adoption Trend for provider info rating vs attitude')
plt.show()

# %%
df.to_excel('dataframe.xlsx')

# %%
df.head().to_csv('df_head.csv')
